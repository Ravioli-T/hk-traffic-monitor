# %% [markdown]
# # Exploratory Data Analysis — HK Traffic Data
#
# This notebook outlines the EDA plan for the Hong Kong traffic monitoring dataset.
#
# ## Plan
#
# 1. **Data completeness:** % valid readings by detector, by district
# 2. **Temporal patterns:** hourly/daily traffic volume & speed distributions
# 3. **Spatial coverage:** map of detector locations
# 4. **Strategic vs. lamppost comparison**
# 5. **Missing data patterns**

# %%
import pandas as pd
import sys
from pathlib import Path

# Add project root
sys.path.insert(0, str(Path.cwd().parent))

# TODO: Load config, connect to DB
# from config import settings
# from src.database.connection import get_engine
# df_readings = pd.read_sql("SELECT * FROM traffic_readings LIMIT 1000", get_engine())
# df_detectors = pd.read_sql("SELECT * FROM detector_info", get_engine())

# %% [markdown]
# ## 1. Data completeness
#
# TODO: Compute % valid readings by detector, by district. Visualize with bar charts.

# %%
# TODO: df_readings.groupby('detector_id')['valid'].value_counts(normalize=True)
# TODO: df_readings.merge(df_detectors).groupby('district')['valid'].value_counts(normalize=True)

# %% [markdown]
# ## 2. Temporal patterns
#
# TODO: Extract hour/day from timestamp, plot volume & speed distributions.

# %%
# TODO: df_readings['hour'] = pd.to_datetime(df_readings['timestamp']).dt.hour
# TODO: df_readings['day_of_week'] = pd.to_datetime(df_readings['timestamp']).dt.dayofweek
# TODO: Plot hourly/daily aggregates

# %% [markdown]
# ## 3. Spatial coverage
#
# TODO: Map detector locations (latitude, longitude) using folium or similar.

# %%
# TODO: import folium
# TODO: m = folium.Map(location=[22.3, 114.2], zoom_start=11)
# TODO: Add markers for each detector

# %% [markdown]
# ## 4. Strategic vs. lamppost comparison
#
# TODO: Compare volume, speed, occupancy distributions between source types.

# %%
# TODO: df_readings.groupby('source_type').agg({'speed': 'mean', 'volume': 'sum', ...})

# %% [markdown]
# ## 5. Missing data patterns
#
# TODO: Identify time gaps, detector downtime, null patterns.

# %%
# TODO: df_readings.isnull().sum()
# TODO: Time series of missingness by detector
